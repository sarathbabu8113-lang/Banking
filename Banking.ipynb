# %%
pip install mysql-connector-python
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import mysql.connector
import numpy as np
import pandas as pd

# %%
ds=pd.read_excel('data.xlsx')

# %%
ds.head()
# Out:
#    UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    417566             53278       61360  89.63         67        22807
# 2    539055             52378       60300  88.39         67        22807
# 3    529269             46349       61500  76.42         67        22807
# 4    563215             43594       78256  57.50         67        22744
#
#    manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  ...  \
# 0               45                1441    1984-01-01        Salaried  ...
# 1               45                1497    1985-08-24   Self employed  ...
# 2               45                1495    1977-12-09   Self employed  ...
# 3               45                1502    1988-06-01        Salaried  ...
# 4               86                1499    1994-07-14   Self employed  ...
#
#   SEC.SANCTIONED.AMOUNT  SEC.DISBURSED.AMOUNT  PRIMARY.INSTAL.AMT  \
# ...

# %%
ds.tail()
# Out:
#         UniqueID  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 233149    561031             57759       76350  77.28          5        22289
# 233150    649600             55009       71200  78.72        138        17408
# 233151    603445             58513       68000  88.24        135        23313
# 233152    442948             22824       40458  61.79        160        16212
# 233153    545300             35299       72698  52.27          3        14573
#
#         manufacturer_id  Current_pincode_ID Date.of.Birth Employment.Type  \
# 233149               51                3326    1981-11-10   Self employed
# 233150               51                3385    1992-10-15   Self employed
# 233151               45                1797    1981-12-19   Self employed
# 233152               48                  96    1989-07-31   Self employed
# 233153               45                  17    1968-08-01   Self employed
#
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 233154 entries, 0 to 233153
# Data columns (total 41 columns):
#  #   Column                               Non-Null Count   Dtype
# ---  ------                               --------------   -----
#  0   UniqueID                             233154 non-null  int64
#  1   disbursed_amount                     233154 non-null  int64
#  2   asset_cost                           233154 non-null  int64
#  3   ltv                                  233154 non-null  float64
#  4   branch_id                            233154 non-null  int64
#  5   supplier_id                          233154 non-null  int64
#  6   manufacturer_id                      233154 non-null  int64
#  7   Current_pincode_ID                   233154 non-null  int64
#  8   Date.of.Birth                        233154 non-null  datetime64[ns]
#  9   Employment.Type                      225493 non-null  object
# ...

# %%
ds.isna().sum()
# Out:
# UniqueID                                  0
# disbursed_amount                          0
# asset_cost                                0
# ltv                                       0
# branch_id                                 0
# supplier_id                               0
# manufacturer_id                           0
# Current_pincode_ID                        0
# Date.of.Birth                             0
# Employment.Type                        7661
# DisbursalDate                             0
# State_ID                                  0
# Employee_code_ID                          0
# MobileNo_Avl_Flag                         0
# Aadhar_flag                               0
# PAN_flag                                  0
# VoterID_flag                              0
# Driving_flag                              0
# Passport_flag                             0
# PERFORM_CNS.SCORE                         0
# PERFORM_CNS.SCORE.DESCRIPTION             0
# ...

# %%
mode_value = ds['Employment.Type'].mode()[0]
ds['Employment.Type']=ds['Employment.Type'].fillna(mode_value)

# %%
ds.isna().sum()
# Out:
# UniqueID                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# Current_pincode_ID                     0
# Date.of.Birth                          0
# Employment.Type                        0
# DisbursalDate                          0
# State_ID                               0
# Employee_code_ID                       0
# MobileNo_Avl_Flag                      0
# Aadhar_flag                            0
# PAN_flag                               0
# VoterID_flag                           0
# Driving_flag                           0
# Passport_flag                          0
# PERFORM_CNS.SCORE                      0
# PERFORM_CNS.SCORE.DESCRIPTION          0
# PRI.NO.OF.ACCTS                        0
# PRI.ACTIVE.ACCTS                       0
# ...

# %%
ds1=ds.rename(columns=str.lower)
print(ds.columns)
# Out:
# Index(['UniqueID', 'disbursed_amount', 'asset_cost', 'ltv', 'branch_id',
#        'supplier_id', 'manufacturer_id', 'Current_pincode_ID', 'Date.of.Birth',
#        'Employment.Type', 'DisbursalDate', 'State_ID', 'Employee_code_ID',
#        'MobileNo_Avl_Flag', 'Aadhar_flag', 'PAN_flag', 'VoterID_flag',
#        'Driving_flag', 'Passport_flag', 'PERFORM_CNS.SCORE',
#        'PERFORM_CNS.SCORE.DESCRIPTION', 'PRI.NO.OF.ACCTS', 'PRI.ACTIVE.ACCTS',
#        'PRI.OVERDUE.ACCTS', 'PRI.CURRENT.BALANCE', 'PRI.SANCTIONED.AMOUNT',
#        'PRI.DISBURSED.AMOUNT', 'SEC.NO.OF.ACCTS', 'SEC.ACTIVE.ACCTS',
#        'SEC.OVERDUE.ACCTS', 'SEC.CURRENT.BALANCE', 'SEC.SANCTIONED.AMOUNT',
#        'SEC.DISBURSED.AMOUNT', 'PRIMARY.INSTAL.AMT', 'SEC.INSTAL.AMT',
#        'NEW.ACCTS.IN.LAST.SIX.MONTHS', 'DELINQUENT.ACCTS.IN.LAST.SIX.MONTHS',
#        'AVERAGE.ACCT.AGE', 'CREDIT.HISTORY.LENGTH', 'NO.OF_INQUIRIES',
#        'loan_default'],
#       dtype='object')

# %%
ds1.columns=ds.columns.str.replace(".","_")

# %%
ds1=ds1.rename(columns=str.lower)

# %%
ds1.head()
# Out:
#    uniqueid  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    417566             53278       61360  89.63         67        22807
# 2    539055             52378       60300  88.39         67        22807
# 3    529269             46349       61500  76.42         67        22807
# 4    563215             43594       78256  57.50         67        22744
#
#    manufacturer_id  current_pincode_id date_of_birth employment_type  ...  \
# 0               45                1441    1984-01-01        Salaried  ...
# 1               45                1497    1985-08-24   Self employed  ...
# 2               45                1495    1977-12-09   Self employed  ...
# 3               45                1502    1988-06-01        Salaried  ...
# 4               86                1499    1994-07-14   Self employed  ...
#
#   sec_sanctioned_amount  sec_disbursed_amount  primary_instal_amt  \
# ...

# %%
ds1.describe()
# Out:
#             uniqueid  disbursed_amount    asset_cost            ltv  \
# count  233154.000000     233154.000000  2.331540e+05  233154.000000
# mean   535917.573376      54356.993528  7.586507e+04      74.746530
# min    417428.000000      13320.000000  3.700000e+04      10.030000
# 25%    476786.250000      47145.000000  6.571700e+04      68.880000
# 50%    535978.500000      53803.000000  7.094600e+04      76.800000
# 75%    595039.750000      60413.000000  7.920175e+04      83.670000
# max    671084.000000     990572.000000  1.628992e+06      95.000000
# std     68315.693711      12971.314171  1.894478e+04      11.456636
#
#            branch_id    supplier_id  manufacturer_id  current_pincode_id  \
# count  233154.000000  233154.000000    233154.000000       233154.000000
# mean       72.936094   19638.635035        69.028054         3396.880247
# min         1.000000   10524.000000        45.000000            1.000000
# ...

# %%
ds1.isna().sum()
# Out:
# uniqueid                               0
# disbursed_amount                       0
# asset_cost                             0
# ltv                                    0
# branch_id                              0
# supplier_id                            0
# manufacturer_id                        0
# current_pincode_id                     0
# date_of_birth                          0
# employment_type                        0
# disbursaldate                          0
# state_id                               0
# employee_code_id                       0
# mobileno_avl_flag                      0
# aadhar_flag                            0
# pan_flag                               0
# voterid_flag                           0
# driving_flag                           0
# passport_flag                          0
# perform_cns_score                      0
# perform_cns_score_description          0
# pri_no_of_accts                        0
# pri_active_accts                       0
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(x='loan_default', data=ds1)
plt.title('Loan Default Count')
plt.xlabel('Loan Default(0=No,1=Yes)')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
ds1['loan_default'].value_counts()
# Out:
# loan_default
# 0    182543
# 1     50611
# Name: count, dtype: int64

# %%
ds1['loan_default'].value_counts().plot(
    kind='pie',
    autopct='1%.1f%%',
    labels=['Non-Default','Default'])
plt.title('Loan Default Distribution')
plt.ylabel('')
plt.show()

# %%
###Loan Default by State
plt.figure(figsize=(12,5))
sns.countplot(x='state_id',hue='loan_default',data=ds1)
plt.title('Loan Default by State')
plt.xlabel('State')
plt.show()

# %%
##Loan default by branch
plt.figure(figsize=(12,5))
sns.countplot(x='branch_id',hue='loan_default',data=ds1)
plt.title('Loan Default by Branch')
plt.xlabel('Branch')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
#Loan Default by Supplier
top_suppliers = ds1['supplier_id'].value_counts().head(10).index

sns.countplot(x='supplier_id', hue='loan_default',
              data=ds1[ds1['supplier_id'].isin(top_suppliers)])

plt.title('Top Suppliers vs Default')
plt.show()

# %%
#Loan Default by Manufrature
plt.figure(figsize=(12,5))
sns.countplot(x='manufacturer_id',hue='loan_default',data=ds1)
plt.title('Loan Default by Manufacture ID')
plt.xlabel('Manufacture ID')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.show()

# %%
from mysql.connector import errorcode

# Replace with your MySQL server details
config = {
    'host': '127.0.0.1',      # e.g., 'localhost' or an IP address
    'user': 'root',      # e.g., 'root'
    'password': 'Geetha@1973',
    'database': 'banking' 
}

try:
    conn = mysql.connector.connect(**config)
    print("Connection successful!")
except mysql.connector.Error as err:
    if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
        print("Something is wrong with your user name or password")
    elif err.errno == errorcode.ER_BAD_DB_ERROR:
        print("Database does not exist")
    else:
        print(err)
# Out:
# Connection successful!

# %%
# !pip install SQLAlchemy

# %%
from sqlalchemy import create_engine
from urllib.parse import quote_plus

df_cleaned = ds1.copy()

password = quote_plus("Geetha@1973")

engine = create_engine(
    f'mysql+mysqlconnector://root:{password}@localhost/banking'
)

df_cleaned.to_sql(
    name='loan_data',
    con=engine,
    if_exists='replace',
    index=False,
    chunksize=500,
    method='multi'
)

print("Done")
# Out:
# Done

# %%
df_cleaned.to_sql(
    name='loan_data',
    con=engine,
    if_exists='replace',
    index=False,
    chunksize=1000   # 👈 KEY FIX
)
# Out:
# 233154

# %%
from sqlalchemy import create_engine

# Make sure config is defined properly
config = {
    "user": "root",
    "password": quote_plus("Geetha@1973"),
    "host": "localhost",
    "database": "banking"
}

# Create engine
engine = create_engine(
    f'mysql+mysqlconnector://{config["user"]}:{config["password"]}@{config["host"]}/{config["database"]}'
)

# Upload dataframe
df_cleaned.to_sql(
    name='loan_data',
    con=engine,
    if_exists='replace',
    index=False,
    chunksize=500,      # 🔥 reduce memory load
    method='multi'      # 🔥 efficient insert
)
print("Data successfully uploaded to MySQL.")
# Out:
# Data successfully uploaded to MySQL.

# %%
df_cleaned.head()
# Out:
#    uniqueid  disbursed_amount  asset_cost    ltv  branch_id  supplier_id  \
# 0    420825             50578       58400  89.55         67        22807
# 1    417566             53278       61360  89.63         67        22807
# 2    539055             52378       60300  88.39         67        22807
# 3    529269             46349       61500  76.42         67        22807
# 4    563215             43594       78256  57.50         67        22744
#
#    manufacturer_id  current_pincode_id date_of_birth employment_type  ...  \
# 0               45                1441    1984-01-01        Salaried  ...
# 1               45                1497    1985-08-24   Self employed  ...
# 2               45                1495    1977-12-09   Self employed  ...
# 3               45                1502    1988-06-01        Salaried  ...
# 4               86                1499    1994-07-14   Self employed  ...
#
#   sec_sanctioned_amount  sec_disbursed_amount  primary_instal_amt  \
# ...

# %%
ds1.to_csv('loan_data_cleaned1.csv', index=False)
